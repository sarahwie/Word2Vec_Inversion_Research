# %%
import pickle
import sys
import datetime
import pandas as pd
import numpy as np
import nltk.data
import multiprocessing
from copy import deepcopy
from gensim.models import Word2Vec
import sklearn.metrics as metrics 
from sklearn.cross_validation import StratifiedKFold
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
# Out:
# /nlp-vm/anaconda2/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# ### Read in datafile

# %%
# Read data from files
df = pd.read_csv( 'labeledTrainData.tsv', header=0, delimiter="\t", quoting=3 )
unlabeled_train = pd.read_csv( "unlabeledTrainData.tsv", header=0,  delimiter="\t", quoting=3 )

# %%
df[0:2]
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...

# %%
df['review'].loc[0]
# Out:
# '"With all this stuff going down at the moment with MJ i\'ve started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ\'s feeling towards the press and also the obvious message of drugs are bad m\'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally starts is only on for 20 minutes or so excluding the Smooth Criminal sequence and Joe Pesci is convincing as a psychopathic all powerful drug lord. Why he wants MJ dead so bad is beyond me. Because MJ overheard his plans? Nah, Joe Pesci\'s character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno, maybe he just hates MJ\'s music.<br /><br />Lots of cool things in this like MJ turning into a car and a robot and the whole Speed Demon sequence. Also, the director must have had the patience of a saint when it came to filming the kiddy Bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene.<br /><br />Bottom line, this movie is for people who like MJ on one level or another (which i think is most people). If not, then stay away. It does try and give off a wholesome message and ironically MJ\'s bestest buddy in this movie is a girl! Michael Jackson is truly one of the most talented people ever to grace this planet but is he guilty? Well, with all the attention i\'ve gave this subject....hmmm well i don\'t know because people can be different behind closed doors, i know this for a fact. He is either an extremely nice but stupid guy or one of the most sickest liars. I hope he is not the latter."'

# %%
print len(df)
print df["review"].size
# Out:
# 25000
# 25000

# %%
df.columns = ['id', 'boolean_label', 'abstract']

# %%
df[0:2]
# Out:
#          id  boolean_label                                           abstract
# 0  "5814_8"              1  "With all this stuff going down at the moment ...
# 1  "2381_9"              1  "\"The Classic War of the Worlds\" by Timothy ...

# %% [markdown]
# ### Check label distribution

# %%
#we are concerned about rating
print len(df.loc[df['boolean_label'] == 1])
print len(df.loc[df['boolean_label'] == 0])
# Out:
# 12500
# 12500

# %% [markdown]
# ### Read in indices objects from pickle

# %%
trainIndices = pickle.load(open('trainIndicesMR.p','rb'))
testIndices = pickle.load(open('testIndicesMR.p','rb'))

# %%
print(len(trainIndices[0]))
print(len(testIndices))
# Out:
# 5
# 25

# %% [markdown]
# ### Apply Word2Vec Inversion to get sentence scores

# %%
"""
docprob takes two lists
* docs: a list of documents, each of which is a list of sentences
* models: the candidate word2vec models (each potential class)

it returns the array of class probabilities.  Everything is done in-memory.
"""

def docprobsentences(docs, mods):
    # score() takes a list [s] of sentences here; could also be a sentence generator
    sentlist = [s for d in docs for s in d]
    # the log likelihood of each sentence in this review under each w2v representation
    llhd = np.array( [ m.score(sentlist, len(sentlist)) for m in mods ] )
    # now exponentiate to get likelihoods, 
    lhd = np.exp(llhd - llhd.max(axis=0)) # subtract row max to avoid numeric overload
    # normalize across models (stars) to get sentence-star probabilities
    #all this transposing business does is make it so the total probability of a word 
    #   equals 1 between the 2 arrays (positive prob and negative).
    #and the pandas data frame just puts everything into rows/columns format for easy viz
    prob = pd.DataFrame( (lhd/lhd.sum(axis=0)).transpose() )
    # and finally average the sentence probabilities to get the review probability
    prob["doc"] = [i for i,d in enumerate(docs) for s in d]
    #prob = prob.groupby("doc").mean()
    return prob

# %%
def getFeatures(probssentences_train, train1):
    features = np.zeros((np.unique(probssentences_train["doc"]).shape[0],11))
    label = []
    for doc in np.unique(probssentences_train["doc"]):
        inx = np.where(probssentences_train["doc"] == doc)[0]
        subset = probssentences_train[0].iloc[inx]
        score = train1['boolean_label'].iloc[doc]
        label.append(score)

        inxFirst = inx[0]
        inxLast = inx[-1]

        features[doc,0] = np.mean(subset) #mean of scores
        features[doc,1] = np.min(subset) #min score
        features[doc,2] = np.max(subset) #max score
        features[doc,3] = np.std(subset) #stdev of scores
        features[doc,4] = probssentences_train[0].iloc[inxFirst] #score of first sentence
        features[doc,5] = probssentences_train[0].iloc[inxLast] #score of last sentences
        features[doc,6] = len(subset) #number of sentences
        features[doc,7] = np.mean(                               #sigmoid (with k = 10)
                            1./(1+np.exp(-10*
                               subset.astype(float)-0.5 ))) 
        features[doc,8] = np.mean(                               #sigmoid (with k = 20)
                            1./(1+np.exp(-20*
                               subset.astype(float)-0.5 )))
        features[doc,9] = np.argmin(subset)-inxFirst #position of min score
        features[doc,10] = np.argmax(subset)-inxFirst #position of max score
    
    return (features, label)

# %%
def buildModels(train1, test1, docs, docsTrain, basemodel, label):
    
    scoreDT = []
    scoreRF = []
    
    # ****** Split the labeled training set into clean sentences
    #
    sentences_pos = []  # Initialize an empty list of sentences
    sentences_neg = []  # Initialize an empty list of sentences

    inxs_pos = np.where(train1["boolean_label"] == 1)[0].tolist()
    inxs_neg = np.where(train1["boolean_label"] == 0)[0].tolist()

    print "Parsing sentences from training set"
    for inx in inxs_pos:
        review = train1["abstract"].iloc[inx]
        sentences_pos += KaggleWord2VecUtility.review_to_sentences(review, tokenizer)

    for inx in inxs_neg:
        review = train1["abstract"].iloc[inx]
        sentences_neg += KaggleWord2VecUtility.review_to_sentences(review, tokenizer)    

    models = [deepcopy(basemodel) for y in range(2)]
    models[0].train(sentences_neg, total_examples=len(sentences_neg) )
    models[1].train(sentences_pos, total_examples=len(sentences_pos) )

    print "scoring test set"
    # get the probs (note we give docprob our test set plus the models)
    probssentencesArticle = docprobsentences(docs,models).astype(object)

    probssentences_train = docprobsentences(docsTrain,models).astype(object)
        
    #step 1- get training features
    obj = getFeatures(probssentences_train, train1)
    features = obj[0]
    label = obj[1]

    #step 2- build decision tree
    clf = tree.DecisionTreeClassifier(min_samples_leaf=1000)
    clf = clf.fit(features, label)

    print "decision tree performance on self"
    resultTrain = clf.predict(features)

    print metrics.roc_auc_score(label, resultTrain)

    #step 3- build random forest

    forest = RandomForestClassifier()
    forest = forest.fit( features, label )

    print "random forest performance on self"
    resultTrainRF = forest.predict(features)
    print metrics.roc_auc_score(label, resultTrainRF)

    #step 4- get test features
    test = getFeatures(probssentencesArticle, test1)
    featuresT = test[0]
    labelsT = test[1]

    #step 5- get test set performance on decision tree 
    result = clf.predict(featuresT)
    scoreDT.append(metrics.roc_auc_score(labelsT, result))
    scoreDT.append(metrics.accuracy_score(labelsT, result))
    scoreDT.append(metrics.f1_score(labelsT, result))
    scoreDT.append(metrics.precision_score(labelsT, result))
    scoreDT.append(metrics.recall_score(labelsT, result))
    
    print(len(scoreDT))

    #step 6- get test set performance on random forest
    clf2 = forest.predict(featuresT)
    scoreRF.append(metrics.roc_auc_score(labelsT, clf2))
    scoreRF.append(metrics.accuracy_score(labelsT, clf2))
    scoreRF.append(metrics.f1_score(labelsT, clf2))
    scoreRF.append(metrics.precision_score(labelsT, clf2))
    scoreRF.append(metrics.recall_score(labelsT, clf2))
    
    print(len(scoreDT))
    
    return scoreDT, scoreRF, models, probssentencesArticle, probssentences_train, clf, forest, features, featuresT

# %%
a = datetime.datetime.now().replace(microsecond=0)

#CROSS VALIDATION
#r=0-24, our meta-folds

DT_ROCs = []
DT_accuracies = []
DT_F1_scores = []
DT_precisions = []
DT_recalls = []

RF_ROCs = []
RF_accuracies = []
RF_F1_scores = []
RF_precisions = []
RF_recalls = []

for r in range(len(trainIndices)):
    
    print("METAROUND", r+1)

    m = 1

    avgROC_DT = []
    avgACC_DT = []
    avgF1_DT = []
    avgPREC_DT = []
    avgREC_DT = []
    
    avgROC_RF = []
    avgACC_RF = []
    avgF1_RF = []
    avgPREC_RF = []
    avgREC_RF = []
    
    #i=0-4, our 5-folds
    for i in range(len(trainIndices[r])):

        print("ROUND", m)
        m = m + 1
        #use the indexes to subset the df pandas dataframe
        train1, test1 = df.iloc[trainIndices[r][i]], df.iloc[testIndices[r][i]]


        # ****** Split the labeled and unlabeled training sets into clean sentences
        #
        sentences = []  # Initialize an empty list of sentences
        docsTrain = []
        for review in train1["abstract"]:
            result = KaggleWord2VecUtility.review_to_sentences(review, tokenizer)
            sentences += result
            docsTrain.append(result)

        #unlabeled sentences only go into sentences[], not docsTrain[] because have no labels
        print "Parsing sentences from unlabeled set"
        for review in unlabeled_train["review"]:
            result = KaggleWord2VecUtility.review_to_sentences(review, tokenizer)
            sentences += result

        print "Building and training w2v models"
        ## create a w2v learner 
        basemodel = Word2Vec(
            sentences=None,
            size=100, #default
            window=5, #default
            workers=multiprocessing.cpu_count(),   # use your cores
            iter=3, # iter = sweeps of SGD through the data; more is better
            hs=1, negative=0 # we only have scoring for the hierarchical softmax setup
        )
        basemodel.build_vocab(sentences) 

        print "Parsing sentences from test set"
        # read in the test set as a list of a list of words
        docs = []
        for review in test1["abstract"]:
            docs.append(KaggleWord2VecUtility.review_to_sentences(review, tokenizer))

        #START CHECKING AGAIN HERE
        print "Scoring test set"
        tup1 = buildModels(train1, test1, docs, docsTrain, basemodel, 1)
        scoreDT_1 = tup1[0]
        scoreRF_1 = tup1[1]

        avgROC_DT.append(scoreDT_1[0])
        avgACC_DT.append(scoreDT_1[1])
        avgF1_DT.append(scoreDT_1[2])
        avgPREC_DT.append(scoreDT_1[3])
        avgREC_DT.append(scoreDT_1[4])
        
        avgROC_RF.append(scoreRF_1[0])
        avgACC_RF.append(scoreRF_1[1])
        avgF1_RF.append(scoreRF_1[2])
        avgPREC_RF.append(scoreRF_1[3])
        avgREC_RF.append(scoreRF_1[4])
        
    print("average DT ROC:", sum(avgROC_DT)/float(len(avgROC_DT)))
    print("average DT ACC:", sum(avgACC_DT)/float(len(avgACC_DT)))
    print("average DT F1:", sum(avgF1_DT)/float(len(avgF1_DT)))
    print("average DT PREC:", sum(avgPREC_DT)/float(len(avgPREC_DT)))
    print("average DT REC:", sum(avgREC_DT)/float(len(avgREC_DT)))
    
    print("average RF ROC:", sum(avgROC_RF)/float(len(avgROC_RF)))
    print("average RF ACC:", sum(avgACC_RF)/float(len(avgACC_RF)))
    print("average RF F1:", sum(avgF1_RF)/float(len(avgF1_RF)))
    print("average RF PREC:", sum(avgPREC_RF)/float(len(avgPREC_RF)))
    print("average RF REC:", sum(avgREC_RF)/float(len(avgREC_RF)))
    
    
    DT_ROCs.append(sum(avgROC_DT)/float(len(avgROC_DT)))
    DT_accuracies.append(sum(avgACC_DT)/float(len(avgACC_DT)))
    DT_F1_scores.append(sum(avgF1_DT)/float(len(avgF1_DT)))
    DT_precisions.append(sum(avgPREC_DT)/float(len(avgPREC_DT)))
    DT_recalls.append(sum(avgREC_DT)/float(len(avgREC_DT)))
    
        
    RF_ROCs.append(sum(avgROC_RF)/float(len(avgROC_RF)))
    RF_accuracies.append(sum(avgACC_RF)/float(len(avgACC_RF)))
    RF_F1_scores.append(sum(avgF1_RF)/float(len(avgF1_RF)))
    RF_precisions.append(sum(avgPREC_RF)/float(len(avgPREC_RF)))
    RF_recalls.append(sum(avgREC_RF)/float(len(avgREC_RF)))
    
    print("--------------------------------------------------")
  
        
print ""
print "---------------------------------------------------------------------------------"
print ""
print "DECISION TREE FINAL RESULTS"
print("ROCs:")
print(DT_ROCs)
print("accuracies:")
print(DT_accuracies)
print("F1-scores:")
print(DT_F1_scores)
print("precisions:")
print(DT_precisions)
print("recalls:")
print(DT_recalls)

print ""
print "---------------------------------------------------------------------------------"
print ""
print "RANDOM FOREST FINAL RESULTS"
print("ROCs:")
print(RF_ROCs)
print("accuracies:")
print(RF_accuracies)
print("F1-scores:")
print(RF_F1_scores)
print("precisions:")
print(RF_precisions)
print("recalls:")
print(RF_recalls)
    
b = datetime.datetime.now().replace(microsecond=0)
print(b-a)
# Out:
# ('METAROUND', 1)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97295
# random forest performance on self
# 0.99805
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.974
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9739
# random forest performance on self
# 0.99835
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9724
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97235
# random forest performance on self
# 0.9982
# 5
# 5
# ('average DT ROC:', 0.88068000000000013)
# ('average DT ACC:', 0.88068000000000013)
# ('average DT F1:', 0.88259974702825195)
# ('average DT PREC:', 0.86842757912845914)
# ('average DT REC:', 0.89735999999999994)
# ('average RF ROC:', 0.88156000000000001)
# ('average RF ACC:', 0.88156000000000001)
# ('average RF F1:', 0.88171861207602953)
# ('average RF PREC:', 0.88050461559646609)
# ('average RF REC:', 0.88304000000000005)
# --------------------------------------------------
# ('METAROUND', 2)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9735
# random forest performance on self
# 0.99745
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97225
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97325
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9725
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97245
# random forest performance on self
# 0.9969
# 5
# 5
# ('average DT ROC:', 0.88239999999999996)
# ('average DT ACC:', 0.88239999999999996)
# ('average DT F1:', 0.88351297019700892)
# ('average DT PREC:', 0.87521938780754238)
# ('average DT REC:', 0.89224000000000014)
# ('average RF ROC:', 0.88188)
# ('average RF ACC:', 0.88188)
# ('average RF F1:', 0.88233046958804739)
# ('average RF PREC:', 0.87899409529240702)
# ('average RF REC:', 0.88575999999999999)
# --------------------------------------------------
# ('METAROUND', 3)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9731
# random forest performance on self
# 0.997
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97135
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97345
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.971
# random forest performance on self
# 0.99745
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9725
# random forest performance on self
# 0.99675
# 5
# 5
# ('average DT ROC:', 0.87983999999999996)
# ('average DT ACC:', 0.87984000000000007)
# ('average DT F1:', 0.88069187107330626)
# ('average DT PREC:', 0.87428896204791628)
# ('average DT REC:', 0.88735999999999993)
# ('average RF ROC:', 0.88071999999999995)
# ('average RF ACC:', 0.88071999999999995)
# ('average RF F1:', 0.88101323340910409)
# ('average RF PREC:', 0.87904050952203239)
# ('average RF REC:', 0.88304000000000005)
# --------------------------------------------------
# ('METAROUND', 4)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97345
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97175
# random forest performance on self
# 0.9971
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97225
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97295
# random forest performance on self
# 0.9975
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.973
# random forest performance on self
# 0.9971
# 5
# 5
# ('average DT ROC:', 0.87991999999999992)
# ('average DT ACC:', 0.87991999999999992)
# ('average DT F1:', 0.88174533979339498)
# ('average DT PREC:', 0.86848599451668151)
# ('average DT REC:', 0.89544000000000001)
# ('average RF ROC:', 0.88003999999999993)
# ('average RF ACC:', 0.88003999999999993)
# ('average RF F1:', 0.88035509276964541)
# ('average RF PREC:', 0.87797478212403601)
# ('average RF REC:', 0.88279999999999992)
# --------------------------------------------------
# ('METAROUND', 5)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97315
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97125
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97085
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97225
# random forest performance on self
# 0.9976
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97305
# random forest performance on self
# 0.9972
# 5
# 5
# ('average DT ROC:', 0.88019999999999998)
# ('average DT ACC:', 0.88019999999999998)
# ('average DT F1:', 0.88198054226286049)
# ('average DT PREC:', 0.86937722639497506)
# ('average DT REC:', 0.89512000000000003)
# ('average RF ROC:', 0.87823999999999991)
# ('average RF ACC:', 0.87824000000000013)
# ('average RF F1:', 0.87869296905622873)
# ('average RF PREC:', 0.87535330744157558)
# ('average RF REC:', 0.88207999999999998)
# --------------------------------------------------
# ('METAROUND', 6)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97365
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97305
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97215
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.973
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9741
# random forest performance on self
# 0.9975
# 5
# 5
# ('average DT ROC:', 0.88048000000000004)
# ('average DT ACC:', 0.88048000000000004)
# ('average DT F1:', 0.8818850350320504)
# ('average DT PREC:', 0.87157398401965902)
# ('average DT REC:', 0.89247999999999994)
# ('average RF ROC:', 0.88236000000000003)
# ('average RF ACC:', 0.88235999999999992)
# ('average RF F1:', 0.8822806798289401)
# ('average RF PREC:', 0.88300193022707707)
# ('average RF REC:', 0.88168000000000002)
# --------------------------------------------------
# ('METAROUND', 7)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97405
# random forest performance on self
# 0.9979
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97135
# random forest performance on self
# 0.99725
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9729
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97255
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9731
# random forest performance on self
# 0.99735
# 5
# 5
# ('average DT ROC:', 0.88156000000000001)
# ('average DT ACC:', 0.88156000000000001)
# ('average DT F1:', 0.88181539514235807)
# ('average DT PREC:', 0.88007317141075525)
# ('average DT REC:', 0.88360000000000005)
# ('average RF ROC:', 0.88403999999999994)
# ('average RF ACC:', 0.88403999999999994)
# ('average RF F1:', 0.88455886274789819)
# ('average RF PREC:', 0.88070665444915597)
# ('average RF REC:', 0.88848000000000005)
# --------------------------------------------------
# ('METAROUND', 8)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97345
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9718
# random forest performance on self
# 0.99675
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97335
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97265
# random forest performance on self
# 0.9975
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97255
# random forest performance on self
# 0.9976
# 5
# 5
# ('average DT ROC:', 0.87988)
# ('average DT ACC:', 0.87988)
# ('average DT F1:', 0.88239821533581753)
# ('average DT PREC:', 0.86451930010785571)
# ('average DT REC:', 0.90127999999999986)
# ('average RF ROC:', 0.88260000000000005)
# ('average RF ACC:', 0.88260000000000005)
# ('average RF F1:', 0.88305407280069248)
# ('average RF PREC:', 0.87973558969396559)
# ('average RF REC:', 0.88647999999999993)
# --------------------------------------------------
# ('METAROUND', 9)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9723
# random forest performance on self
# 0.99755
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9717
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.972
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97355
# random forest performance on self
# 0.99755
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9735
# random forest performance on self
# 0.99695
# 5
# 5
# ('average DT ROC:', 0.87900000000000011)
# ('average DT ACC:', 0.87900000000000011)
# ('average DT F1:', 0.88010263529633492)
# ('average DT PREC:', 0.87208718443837996)
# ('average DT REC:', 0.88832)
# ('average RF ROC:', 0.88075999999999988)
# ('average RF ACC:', 0.88075999999999988)
# ('average RF F1:', 0.88109411227013135)
# ('average RF PREC:', 0.87861115078906649)
# ('average RF REC:', 0.88368000000000002)
# --------------------------------------------------
# ('METAROUND', 10)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97315
# random forest performance on self
# 0.998
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97305
# random forest performance on self
# 0.9978
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9736
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9724
# random forest performance on self
# 0.9967
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97275
# random forest performance on self
# 0.997
# 5
# 5
# ('average DT ROC:', 0.87963999999999998)
# ('average DT ACC:', 0.87963999999999998)
# ('average DT F1:', 0.88203569016059569)
# ('average DT PREC:', 0.86491608875468695)
# ('average DT REC:', 0.89992000000000005)
# ('average RF ROC:', 0.87967999999999991)
# ('average RF ACC:', 0.87968000000000013)
# ('average RF F1:', 0.8801649705604957)
# ('average RF PREC:', 0.87661107178776176)
# ('average RF REC:', 0.88375999999999999)
# --------------------------------------------------
# ('METAROUND', 11)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9719
# random forest performance on self
# 0.9979
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97295
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97205
# random forest performance on self
# 0.99685
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97265
# random forest performance on self
# 0.9971
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9734
# random forest performance on self
# 0.9967
# 5
# 5
# ('average DT ROC:', 0.87660000000000005)
# ('average DT ACC:', 0.87660000000000005)
# ('average DT F1:', 0.87849643575459768)
# ('average DT PREC:', 0.86552346958382709)
# ('average DT REC:', 0.89215999999999995)
# ('average RF ROC:', 0.88063999999999998)
# ('average RF ACC:', 0.88063999999999998)
# ('average RF F1:', 0.88088835528733145)
# ('average RF PREC:', 0.87903854998788944)
# ('average RF REC:', 0.88279999999999992)
# --------------------------------------------------
# ('METAROUND', 12)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9727
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97195
# random forest performance on self
# 0.9965
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9731
# random forest performance on self
# 0.9969
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97205
# random forest performance on self
# 0.99775
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9726
# random forest performance on self
# 0.9976
# 5
# 5
# ('average DT ROC:', 0.8787600000000001)
# ('average DT ACC:', 0.8787600000000001)
# ('average DT F1:', 0.88023383879347183)
# ('average DT PREC:', 0.86968465058014832)
# ('average DT REC:', 0.89128000000000007)
# ('average RF ROC:', 0.87948000000000004)
# ('average RF ACC:', 0.87948000000000004)
# ('average RF F1:', 0.87986690998982531)
# ('average RF PREC:', 0.87710448857999546)
# ('average RF REC:', 0.88271999999999995)
# --------------------------------------------------
# ('METAROUND', 13)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97085
# random forest performance on self
# 0.99705
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97255
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9731
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97365
# random forest performance on self
# 0.99705
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97255
# random forest performance on self
# 0.99755
# 5
# 5
# ('average DT ROC:', 0.88000000000000012)
# ('average DT ACC:', 0.88000000000000012)
# ('average DT F1:', 0.88108467833522874)
# ('average DT PREC:', 0.87335379625935583)
# ('average DT REC:', 0.88903999999999994)
# ('average RF ROC:', 0.87907999999999986)
# ('average RF ACC:', 0.87908000000000008)
# ('average RF F1:', 0.87928188470618307)
# ('average RF PREC:', 0.87790703724260621)
# ('average RF REC:', 0.88072000000000017)
# --------------------------------------------------
# ('METAROUND', 14)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9743
# random forest performance on self
# 0.9976
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9742
# random forest performance on self
# 0.99685
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9727
# random forest performance on self
# 0.99785
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9725
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97185
# random forest performance on self
# 0.9965
# 5
# 5
# ('average DT ROC:', 0.88219999999999987)
# ('average DT ACC:', 0.88219999999999987)
# ('average DT F1:', 0.8821747015799758)
# ('average DT PREC:', 0.88251004643337971)
# ('average DT REC:', 0.88192000000000004)
# ('average RF ROC:', 0.88239999999999996)
# ('average RF ACC:', 0.88239999999999996)
# ('average RF F1:', 0.88216899887166655)
# ('average RF PREC:', 0.88398157046907166)
# ('average RF REC:', 0.88040000000000007)
# --------------------------------------------------
# ('METAROUND', 15)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97275
# random forest performance on self
# 0.9975
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9718
# random forest performance on self
# 0.99755
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9713
# random forest performance on self
# 0.9978
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9713
# random forest performance on self
# 0.99675
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97015
# random forest performance on self
# 0.9972
# 5
# 5
# ('average DT ROC:', 0.87779999999999991)
# ('average DT ACC:', 0.87779999999999991)
# ('average DT F1:', 0.88000400574859339)
# ('average DT PREC:', 0.86447381766512188)
# ('average DT REC:', 0.89648000000000005)
# ('average RF ROC:', 0.88019999999999998)
# ('average RF ACC:', 0.88019999999999998)
# ('average RF F1:', 0.88048528110335911)
# ('average RF PREC:', 0.87839402219391227)
# ('average RF REC:', 0.88263999999999998)
# --------------------------------------------------
# ('METAROUND', 16)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9732
# random forest performance on self
# 0.9978
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97125
# random forest performance on self
# 0.99785
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.973
# random forest performance on self
# 0.99725
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9741
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97265
# random forest performance on self
# 0.9971
# 5
# 5
# ('average DT ROC:', 0.87895999999999996)
# ('average DT ACC:', 0.87895999999999996)
# ('average DT F1:', 0.88044166707073346)
# ('average DT PREC:', 0.87002919170114035)
# ('average DT REC:', 0.89127999999999985)
# ('average RF ROC:', 0.88127999999999995)
# ('average RF ACC:', 0.88128000000000006)
# ('average RF F1:', 0.88135827575975922)
# ('average RF PREC:', 0.88084354597910275)
# ('average RF REC:', 0.88191999999999982)
# --------------------------------------------------
# ('METAROUND', 17)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9739
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97245
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97285
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9701
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97285
# random forest performance on self
# 0.9978
# 5
# 5
# ('average DT ROC:', 0.87992000000000004)
# ('average DT ACC:', 0.87991999999999992)
# ('average DT F1:', 0.88185375953705791)
# ('average DT PREC:', 0.86821569070607263)
# ('average DT REC:', 0.89616000000000007)
# ('average RF ROC:', 0.88156000000000001)
# ('average RF ACC:', 0.88156000000000001)
# ('average RF F1:', 0.88172161157112094)
# ('average RF PREC:', 0.88064614989104384)
# ('average RF REC:', 0.88288000000000011)
# --------------------------------------------------
# ('METAROUND', 18)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9727
# random forest performance on self
# 0.99775
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97205
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97295
# random forest performance on self
# 0.99795
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97385
# random forest performance on self
# 0.9975
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9711
# random forest performance on self
# 0.9976
# 5
# 5
# ('average DT ROC:', 0.87799999999999989)
# ('average DT ACC:', 0.87800000000000011)
# ('average DT F1:', 0.88026555790317507)
# ('average DT PREC:', 0.86406653259493726)
# ('average DT REC:', 0.8972)
# ('average RF ROC:', 0.87939999999999985)
# ('average RF ACC:', 0.87940000000000007)
# ('average RF F1:', 0.87992253344797999)
# ('average RF PREC:', 0.87612892806842024)
# ('average RF REC:', 0.88375999999999999)
# --------------------------------------------------
# ('METAROUND', 19)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9727
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97195
# random forest performance on self
# 0.997
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.973
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9736
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9725
# random forest performance on self
# 0.9975
# 5
# 5
# ('average DT ROC:', 0.87895999999999996)
# ('average DT ACC:', 0.87895999999999996)
# ('average DT F1:', 0.88163491372132263)
# ('average DT PREC:', 0.86276490962154573)
# ('average DT REC:', 0.90151999999999999)
# ('average RF ROC:', 0.88139999999999996)
# ('average RF ACC:', 0.88139999999999996)
# ('average RF F1:', 0.88195681388594205)
# ('average RF PREC:', 0.87785055995056993)
# ('average RF REC:', 0.88615999999999995)
# --------------------------------------------------
# ('METAROUND', 20)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9718
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97305
# random forest performance on self
# 0.9976
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9733
# random forest performance on self
# 0.99735
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9715
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97215
# random forest performance on self
# 0.99795
# 5
# 5
# ('average DT ROC:', 0.88124000000000002)
# ('average DT ACC:', 0.88124000000000002)
# ('average DT F1:', 0.88296695296262828)
# ('average DT PREC:', 0.870417904052044)
# ('average DT REC:', 0.8960800000000001)
# ('average RF ROC:', 0.88139999999999996)
# ('average RF ACC:', 0.88139999999999996)
# ('average RF F1:', 0.88166407319813622)
# ('average RF PREC:', 0.87980737734861925)
# ('average RF REC:', 0.88360000000000005)
# --------------------------------------------------
# ('METAROUND', 21)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97125
# random forest performance on self
# 0.99755
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9732
# random forest performance on self
# 0.9977
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97245
# random forest performance on self
# 0.99795
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9726
# random forest performance on self
# 0.9978
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9705
# random forest performance on self
# 0.997
# 5
# 5
# ('average DT ROC:', 0.87728000000000006)
# ('average DT ACC:', 0.87728000000000006)
# ('average DT F1:', 0.87849636094384231)
# ('average DT PREC:', 0.86997647941907341)
# ('average DT REC:', 0.88735999999999993)
# ('average RF ROC:', 0.87872000000000006)
# ('average RF ACC:', 0.87872000000000006)
# ('average RF F1:', 0.87901642303058214)
# ('average RF PREC:', 0.87684934661254843)
# ('average RF REC:', 0.88119999999999998)
# --------------------------------------------------
# ('METAROUND', 22)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97295
# random forest performance on self
# 0.9965
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9732
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9707
# random forest performance on self
# 0.99725
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9716
# random forest performance on self
# 0.99705
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9738
# random forest performance on self
# 0.99715
# 5
# 5
# ('average DT ROC:', 0.87919999999999998)
# ('average DT ACC:', 0.87919999999999998)
# ('average DT F1:', 0.88101457944061123)
# ('average DT PREC:', 0.8680223607105203)
# ('average DT REC:', 0.89456000000000002)
# ('average RF ROC:', 0.87880000000000003)
# ('average RF ACC:', 0.87880000000000003)
# ('average RF F1:', 0.87886681105341657)
# ('average RF PREC:', 0.87864881224941271)
# ('average RF REC:', 0.87919999999999998)
# --------------------------------------------------
# ('METAROUND', 23)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9715
# random forest performance on self
# 0.9975
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9724
# random forest performance on self
# 0.9981
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97375
# random forest performance on self
# 0.9981
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97265
# random forest performance on self
# 0.9972
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9722
# random forest performance on self
# 0.99665
# 5
# 5
# ('average DT ROC:', 0.87827999999999995)
# ('average DT ACC:', 0.87827999999999995)
# ('average DT F1:', 0.88017203586703041)
# ('average DT PREC:', 0.86690002056894644)
# ('average DT REC:', 0.89391999999999994)
# ('average RF ROC:', 0.88048000000000004)
# ('average RF ACC:', 0.88048000000000004)
# ('average RF F1:', 0.88061450529652507)
# ('average RF PREC:', 0.8796716479019091)
# ('average RF REC:', 0.88160000000000005)
# --------------------------------------------------
# ('METAROUND', 24)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97175
# random forest performance on self
# 0.99715
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9709
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97165
# random forest performance on self
# 0.99775
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9718
# random forest performance on self
# 0.99765
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97165
# random forest performance on self
# 0.9976
# 5
# 5
# ('average DT ROC:', 0.88263999999999998)
# ('average DT ACC:', 0.88263999999999998)
# ('average DT F1:', 0.88410634586034365)
# ('average DT PREC:', 0.87320769036631352)
# ('average DT REC:', 0.89544000000000001)
# ('average RF ROC:', 0.88331999999999999)
# ('average RF ACC:', 0.88331999999999999)
# ('average RF F1:', 0.88374198793962988)
# ('average RF PREC:', 0.88049963650269714)
# ('average RF REC:', 0.88704000000000005)
# --------------------------------------------------
# ('METAROUND', 25)
# ('ROUND', 1)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9721
# random forest performance on self
# 0.9974
# 5
# 5
# ('ROUND', 2)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9719
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 3)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97
# random forest performance on self
# 0.9973
# 5
# 5
# ('ROUND', 4)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.97075
# random forest performance on self
# 0.9969
# 5
# 5
# ('ROUND', 5)
# Parsing sentences from unlabeled set
# Building and training w2v models
# Parsing sentences from test set
# Scoring test set
# Parsing sentences from training set
# scoring test set
# decision tree performance on self
# 0.9727
# random forest performance on self
# 0.99815
# 5
# 5
# ('average DT ROC:', 0.88019999999999998)
# ('average DT ACC:', 0.88019999999999998)
# ('average DT F1:', 0.88120082961922797)
# ('average DT PREC:', 0.87384131505998064)
# ('average DT REC:', 0.88880000000000003)
# ('average RF ROC:', 0.87880000000000003)
# ('average RF ACC:', 0.87880000000000003)
# ('average RF F1:', 0.87906305089607673)
# ('average RF PREC:', 0.87709951173248935)
# ('average RF REC:', 0.8811199999999999)
# --------------------------------------------------
#
# ---------------------------------------------------------------------------------
#
# DECISION TREE FINAL RESULTS
# ROCs:
# [0.88068000000000013, 0.88239999999999996, 0.87983999999999996, 0.87991999999999992, 0.88019999999999998, 0.88048000000000004, 0.88156000000000001, 0.87988, 0.87900000000000011, 0.87963999999999998, 0.87660000000000005, 0.8787600000000001, 0.88000000000000012, 0.88219999999999987, 0.87779999999999991, 0.87895999999999996, 0.87992000000000004, 0.87799999999999989, 0.87895999999999996, 0.88124000000000002, 0.87728000000000006, 0.87919999999999998, 0.87827999999999995, 0.88263999999999998, 0.88019999999999998]
# accuracies:
# [0.88068000000000013, 0.88239999999999996, 0.87984000000000007, 0.87991999999999992, 0.88019999999999998, 0.88048000000000004, 0.88156000000000001, 0.87988, 0.87900000000000011, 0.87963999999999998, 0.87660000000000005, 0.8787600000000001, 0.88000000000000012, 0.88219999999999987, 0.87779999999999991, 0.87895999999999996, 0.87991999999999992, 0.87800000000000011, 0.87895999999999996, 0.88124000000000002, 0.87728000000000006, 0.87919999999999998, 0.87827999999999995, 0.88263999999999998, 0.88019999999999998]
# F1-scores:
# [0.88259974702825195, 0.88351297019700892, 0.88069187107330626, 0.88174533979339498, 0.88198054226286049, 0.8818850350320504, 0.88181539514235807, 0.88239821533581753, 0.88010263529633492, 0.88203569016059569, 0.87849643575459768, 0.88023383879347183, 0.88108467833522874, 0.8821747015799758, 0.88000400574859339, 0.88044166707073346, 0.88185375953705791, 0.88026555790317507, 0.88163491372132263, 0.88296695296262828, 0.87849636094384231, 0.88101457944061123, 0.88017203586703041, 0.88410634586034365, 0.88120082961922797]
# precisions:
# [0.86842757912845914, 0.87521938780754238, 0.87428896204791628, 0.86848599451668151, 0.86937722639497506, 0.87157398401965902, 0.88007317141075525, 0.86451930010785571, 0.87208718443837996, 0.86491608875468695, 0.86552346958382709, 0.86968465058014832, 0.87335379625935583, 0.88251004643337971, 0.86447381766512188, 0.87002919170114035, 0.86821569070607263, 0.86406653259493726, 0.86276490962154573, 0.870417904052044, 0.86997647941907341, 0.8680223607105203, 0.86690002056894644, 0.87320769036631352, 0.87384131505998064]
# recalls:
# [0.89735999999999994, 0.89224000000000014, 0.88735999999999993, 0.89544000000000001, 0.89512000000000003, 0.89247999999999994, 0.88360000000000005, 0.90127999999999986, 0.88832, 0.89992000000000005, 0.89215999999999995, 0.89128000000000007, 0.88903999999999994, 0.88192000000000004, 0.89648000000000005, 0.89127999999999985, 0.89616000000000007, 0.8972, 0.90151999999999999, 0.8960800000000001, 0.88735999999999993, 0.89456000000000002, 0.89391999999999994, 0.89544000000000001, 0.88880000000000003]
#
# ---------------------------------------------------------------------------------
#
# RANDOM FOREST FINAL RESULTS
# ROCs:
# [0.88156000000000001, 0.88188, 0.88071999999999995, 0.88003999999999993, 0.87823999999999991, 0.88236000000000003, 0.88403999999999994, 0.88260000000000005, 0.88075999999999988, 0.87967999999999991, 0.88063999999999998, 0.87948000000000004, 0.87907999999999986, 0.88239999999999996, 0.88019999999999998, 0.88127999999999995, 0.88156000000000001, 0.87939999999999985, 0.88139999999999996, 0.88139999999999996, 0.87872000000000006, 0.87880000000000003, 0.88048000000000004, 0.88331999999999999, 0.87880000000000003]
# accuracies:
# [0.88156000000000001, 0.88188, 0.88071999999999995, 0.88003999999999993, 0.87824000000000013, 0.88235999999999992, 0.88403999999999994, 0.88260000000000005, 0.88075999999999988, 0.87968000000000013, 0.88063999999999998, 0.87948000000000004, 0.87908000000000008, 0.88239999999999996, 0.88019999999999998, 0.88128000000000006, 0.88156000000000001, 0.87940000000000007, 0.88139999999999996, 0.88139999999999996, 0.87872000000000006, 0.87880000000000003, 0.88048000000000004, 0.88331999999999999, 0.87880000000000003]
# F1-scores:
# [0.88171861207602953, 0.88233046958804739, 0.88101323340910409, 0.88035509276964541, 0.87869296905622873, 0.8822806798289401, 0.88455886274789819, 0.88305407280069248, 0.88109411227013135, 0.8801649705604957, 0.88088835528733145, 0.87986690998982531, 0.87928188470618307, 0.88216899887166655, 0.88048528110335911, 0.88135827575975922, 0.88172161157112094, 0.87992253344797999, 0.88195681388594205, 0.88166407319813622, 0.87901642303058214, 0.87886681105341657, 0.88061450529652507, 0.88374198793962988, 0.87906305089607673]
# precisions:
# [0.88050461559646609, 0.87899409529240702, 0.87904050952203239, 0.87797478212403601, 0.87535330744157558, 0.88300193022707707, 0.88070665444915597, 0.87973558969396559, 0.87861115078906649, 0.87661107178776176, 0.87903854998788944, 0.87710448857999546, 0.87790703724260621, 0.88398157046907166, 0.87839402219391227, 0.88084354597910275, 0.88064614989104384, 0.87612892806842024, 0.87785055995056993, 0.87980737734861925, 0.87684934661254843, 0.87864881224941271, 0.8796716479019091, 0.88049963650269714, 0.87709951173248935]
# recalls:
# [0.88304000000000005, 0.88575999999999999, 0.88304000000000005, 0.88279999999999992, 0.88207999999999998, 0.88168000000000002, 0.88848000000000005, 0.88647999999999993, 0.88368000000000002, 0.88375999999999999, 0.88279999999999992, 0.88271999999999995, 0.88072000000000017, 0.88040000000000007, 0.88263999999999998, 0.88191999999999982, 0.88288000000000011, 0.88375999999999999, 0.88615999999999995, 0.88360000000000005, 0.88119999999999998, 0.87919999999999998, 0.88160000000000005, 0.88704000000000005, 0.8811199999999999]
# 1 day, 13:03:45

# %%
import scipy.stats as st

st.t.interval(0.95, len(DT_ROCs)-1, loc=np.mean(DT_ROCs), scale=st.sem(DT_ROCs))
# Out:
# (0.87910959982105263, 0.88038160017894762)

# %%
st.t.interval(0.95, len(DT_accuracies)-1, loc=np.mean(DT_accuracies), scale=st.sem(DT_accuracies))
# Out:
# (0.87910959982105263, 0.88038160017894762)

# %%
st.t.interval(0.95, len(DT_F1_scores)-1, loc=np.mean(DT_F1_scores), scale=st.sem(DT_F1_scores))
# Out:
# (0.88075139522546309, 0.88188173313132245)

# %%
st.t.interval(0.95, len(DT_precisions)-1, loc=np.mean(DT_precisions), scale=st.sem(DT_precisions))
# Out:
# (0.86807950339491491, 0.87207703692103067)

# %%
st.t.interval(0.95, len(DT_recalls)-1, loc=np.mean(DT_recalls), scale=st.sem(DT_recalls))
# Out:
# (0.89096441899808798, 0.89514118100191198)

# %%
st.t.interval(0.95, len(RF_ROCs)-1, loc=np.mean(RF_ROCs), scale=st.sem(RF_ROCs))
# Out:
# (0.88012212024758429, 0.88138507975241553)

# %%
st.t.interval(0.95, len(RF_accuracies)-1, loc=np.mean(RF_accuracies), scale=st.sem(RF_accuracies))
# Out:
# (0.88012212024758429, 0.88138507975241553)

# %%
st.t.interval(0.95, len(RF_F1_scores)-1, loc=np.mean(RF_F1_scores), scale=st.sem(RF_F1_scores))
# Out:
# (0.88040370652655042, 0.88166674076502916)

# %%
st.t.interval(0.95, len(RF_precisions)-1, loc=np.mean(RF_precisions), scale=st.sem(RF_precisions))
# Out:
# (0.8781605678580372, 0.87983982347266931)

# %%
st.t.interval(0.95, len(RF_recalls)-1, loc=np.mean(RF_recalls), scale=st.sem(RF_recalls))
# Out:
# (0.88223205984869424, 0.88405274015130575)

# %%
import re
import nltk

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from nltk.corpus import stopwords


class KaggleWord2VecUtility(object):
    """KaggleWord2VecUtility is a utility class for processing raw HTML text into segments for further learning"""

    @staticmethod
    def review_to_wordlist( review, remove_stopwords=False ):
        # Function to convert a document to a sequence of words,
        # optionally removing stop words.  Returns a list of words.
        #
        # 1. Remove HTML
        review_text = BeautifulSoup(review).get_text()
        #
        # 2. Remove non-letters
        review_text = re.sub("[^a-zA-Z]"," ", review_text)
        #
        # 3. Convert words to lower case and split them
        words = review_text.lower().split()
        #
        # 4. Optionally remove stop words (false by default)
        if remove_stopwords:
            stops = set(stopwords.words("english"))
            words = [w for w in words if not w in stops]
        #
        # 5. Return a list of words
        return(words)
    
    @staticmethod
    def review_to_words( review, remove_stopwords=False ):
        # Function to convert a raw review to a string of words
        # The input is a single string (a raw movie review), and 
        # the output is a single string (a preprocessed movie review)
        #
        # 1. Remove HTML
        review_text = BeautifulSoup(review).get_text() 
        #
        # 2. Remove non-letters        
        review_text = re.sub("[^a-zA-Z]", " ", review_text) 
        #
        # 3. Convert to lower case, split into individual words
        words = review_text.lower().split()                             
        #
        # 4. Optionally remove stop words (false by default)
        if remove_stopwords:
            stops = set(stopwords.words("english"))
            words = [w for w in words if not w in stops]   
        #
        # 6. Join the words back into one string separated by space, 
        # and return the result.
        return( " ".join( words ))   

    # Define a function to split a review into parsed sentences
    @staticmethod
    def review_to_sentences( review, tokenizer, remove_stopwords=False ):
        # Function to split a review into parsed sentences. Returns a
        # list of sentences, where each sentence is a list of words
        #
        # 1. Use the NLTK tokenizer to split the paragraph into sentences
        raw_sentences = tokenizer.tokenize(review.decode('utf8').strip())
        #
        # 2. Loop over each sentence
        sentences = []
        for raw_sentence in raw_sentences:
            # If a sentence is empty, skip it
            if len(raw_sentence) > 0:
                # Otherwise, call review_to_wordlist to get a list of words
                sentences.append( KaggleWord2VecUtility.review_to_wordlist( raw_sentence, \
                  remove_stopwords ))
        #
        # Return the list of sentences (each sentence is a list of words,
        # so this returns a list of lists
        return sentences
